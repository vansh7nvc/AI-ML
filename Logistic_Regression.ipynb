# %% [markdown]
# <a href="https://colab.research.google.com/github/vansh7nvc/AI-ML/blob/main/Logistic_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. load the data
# 2. Analyze the data
# 3. Data preparation
# 4. Training
# 5. prediction
# 6. Evaluation

# %% [markdown]
# Load the data

# %%
import pandas as pd
import  numpy as np

# %%
df = pd.read_csv('iris.csv')

# %%
df.head()
# Out:
#      1    2    3    4      spieces
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %% [markdown]
# Data analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.pairplot(df,hue='spieces')

# %% [markdown]
# # observation
# here i am having 4 columns but my observations told me i dont need all the 4 columns.
#
# 1. petalwidth

# %% [markdown]
# # Data preparation

# %%
target = df.spieces

# %%
data = df.loc[:,['1','4']]

# %%
target
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: spieces, Length: 150, dtype: object

# %%
data.head()
# Out:
#      1    4
# 0  5.1  0.2
# 1  4.9  0.2
# 2  4.7  0.2
# 3  4.6  0.2
# 4  5.0  0.2

# %% [markdown]
# # data preprocessing

# %%
from sklearn.preprocessing import StandardScaler

# %%
StandardScaler = StandardScaler().fit_transform(data)
print(StandardScaler)
# Out:
# [[-9.00681170e-01 -1.31297673e+00]
#  [-1.14301691e+00 -1.31297673e+00]
#  [-1.38535265e+00 -1.31297673e+00]
#  [-1.50652052e+00 -1.31297673e+00]
#  [-1.02184904e+00 -1.31297673e+00]
#  [-5.37177559e-01 -1.05003079e+00]
#  [-1.50652052e+00 -1.18150376e+00]
#  [-1.02184904e+00 -1.31297673e+00]
#  [-1.74885626e+00 -1.31297673e+00]
#  [-1.14301691e+00 -1.44444970e+00]
#  [-5.37177559e-01 -1.31297673e+00]
#  [-1.26418478e+00 -1.31297673e+00]
#  [-1.26418478e+00 -1.44444970e+00]
#  [-1.87002413e+00 -1.44444970e+00]
#  [-5.25060772e-02 -1.31297673e+00]
#  [-1.73673948e-01 -1.05003079e+00]
#  [-5.37177559e-01 -1.05003079e+00]
#  [-9.00681170e-01 -1.18150376e+00]
#  [-1.73673948e-01 -1.18150376e+00]
#  [-9.00681170e-01 -1.18150376e+00]
#  [-5.37177559e-01 -1.31297673e+00]
#  [-9.00681170e-01 -1.05003079e+00]
#  [-1.50652052e+00 -1.31297673e+00]
#  [-9.00681170e-01 -9.18557817e-01]
#  [-1.26418478e+00 -1.31297673e+00]
#  [-1.02184904e+00 -1.31297673e+00]
#  [-1.02184904e+00 -1.05003079e+00]
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(StandardScaler,target,test_size=0.2,random_state=10)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# # prediction

# %%
y_pred = classifier.predict(x_test)

# %% [markdown]
# ### evaluation

# %%
from sklearn import metrics
metrics.accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
metrics.confusion_matrix(y_test,y_pred)
# Out:
# array([[10,  0,  0],
#        [ 0, 13,  0],
#        [ 0,  0,  7]])

# %%
classifier.classes_
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)
