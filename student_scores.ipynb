# %% [markdown]
# <a href="https://colab.research.google.com/github/vansh7nvc/AI-ML/blob/main/student_scores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('student_scores.csv')

# %%
df.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
target = df['Scores']
data = df[('Hours')]

# %%
data
# Out:
# 0     2.5
# 1     5.1
# 2     3.2
# 3     8.5
# 4     3.5
# 5     1.5
# 6     9.2
# 7     5.5
# 8     8.3
# 9     2.7
# 10    7.7
# 11    5.9
# 12    4.5
# 13    3.3
# 14    1.1
# 15    8.9
# 16    2.5
# 17    1.9
# 18    6.1
# 19    7.4
# 20    2.7
# 21    4.8
# 22    3.8
# 23    6.9
# 24    7.8
# Name: Hours, dtype: float64

# %%
target
# Out:
# 0     21
# 1     47
# 2     27
# 3     75
# 4     30
# 5     20
# 6     88
# 7     60
# 8     81
# 9     25
# 10    85
# 11    62
# 12    41
# 13    42
# 14    17
# 15    95
# 16    30
# 17    24
# 18    67
# 19    69
# 20    30
# 21    54
# 22    35
# 23    76
# 24    86
# Name: Scores, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(data, target, test_size=0.7, random_state=0)

# %%
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (7,) (7,)
# (18,) (18,)

# %%
x_train.head()
# Out:
# 7     5.5
# 20    2.7
# 3     8.5
# 0     2.5
# 21    4.8
# Name: Hours, dtype: float64

# %%
x_test.head()
# Out:
# 5     1.5
# 2     3.2
# 19    7.4
# 16    2.5
# 11    5.9
# Name: Hours, dtype: float64

# %% [markdown]
# # **Train the model**

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-1287973812> in <cell line: 0>()
#       1 regressor = LinearRegression()
# ----> 2 regressor.fit(x_train, y_train)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     599         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     600
# --> 601         X, y = validate_data(
#     602             self,
#     603             X,
#
# ...

# %%
from IPython import get_ipython
from IPython.display import display
# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %%
df = pd.read_csv('student_scores.csv')
# %%
df.head()
# %%
# Select the 'Hours' column as a DataFrame (2D)
data = df[['Hours']]
target = df['Scores']
# %%
data
# %%
target
# %%
from sklearn.model_selection import train_test_split
# %%
x_train, x_test, y_train, y_test = train_test_split(data, target, test_size=0.7, random_state=0)
# %%
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# %%
x_train.head()
# %%
x_test.head()
# %% [markdown]
# # **Train the model**
# %%
from sklearn.linear_model import LinearRegression
# %%
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# %%
# Out:
# (7, 1) (7,)
# (18, 1) (18,)
# LinearRegression()

# %%
print('y intercept:', regressor.intercept_)
print('slope:', regressor.coef_)
# Out:
# y intercept: 1.0979263522987353
# slope: [9.8479817]

# %%
y_test_pred = regressor.predict(x_test)

# %%
temp_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_test_pred})
temp_df
# Out:
#     Actual  Predicted
# 5       20  15.869899
# 2       27  32.611468
# 19      69  73.972991
# 16      30  25.717881
# 11      62  59.201018
# 22      35  38.520257
# 17      24  19.809092
# 24      86  77.912184
# 23      76  69.049000
# 14      17  11.930706
# 1       47  51.322633
# 10      85  76.927385
# 13      42  33.596266
# 8       81  82.836174
# 6       88  91.699358
# 18      67  61.170615
# 4       30  35.565862
# 9       25  27.687477
